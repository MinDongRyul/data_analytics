# %% [markdown]
# ### area plot(면적 그래프)
#
# - NaN 값이 있으면 자동으로 0으로 채워짐
# - 기본값으로 누적시켜서 작성됨

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# %%
df = pd.DataFrame(np.random.rand(10,4), columns=list('abcd'))
df.head()
# Out:
#           a         b         c         d
# 0  0.335663  0.816402  0.259547  0.397421
# 1  0.152380  0.857707  0.037799  0.942514
# 2  0.626772  0.775260  0.092149  0.545405
# 3  0.215377  0.606769  0.457600  0.267653
# 4  0.906746  0.922362  0.489270  0.412813

# %%
df.plot.area()
# Out:
# <AxesSubplot:>

# %%
df.plot.area(stacked=False)
# Out:
# <AxesSubplot:>

# %%
df.plot.area(stacked=False, grid=True)
# Out:
# <AxesSubplot:>
